# %% [markdown]
# # **Diary**

# %% [markdown]
# ## Generative AI Usage

# %% [markdown]
# - Generated User Stories as I am unfamiliar with the requirements for industry usage
# - Python bugs where solutions I havent found elsewhere

# %% [markdown]
# ## Missing

# %% [markdown]
# - short
# - ___ mixed
# - nan
# - Discount
# - items start with *
# - items start with " "
# - 17129c
# - 20713
# - 20713 wrongly marked
# - 21494
# - 21733 mixed
# - 22467
# - 22719
# - 85123a mixed
# - ?
# - ? sold as sets?
# - ??
# - ?? missing
# - ???
# - ?????
# - ????damages????
# - ????missing
# - ???lost
# - ???missing
# - ?display?
# - ?lost
# - ?missing
# - ?sold as sets?
# - ?sold individually?
# - AMAZON
# - AMAZON FEE
# - Adjust bad debt
# - Adjustment
# - Adjustment by Peter on 24/05/2010 1
# - Adjustment by Peter on Jun 25 2010
# - Adjustment by john on 26/01/2010 16
# - Adjustment by john on 26/01/2010 17
# - Amazon
# - Amazon Adjustment
# - Amazon sold as set
# - Amazon sold sets
# - Bank Charges
# - Breakages
# - Check
#
#
# - WET/MOULDY
